# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.xlabel('Temperature, $^\circ$C', fontsize="15")
plt.ylabel('$\Delta$ efficiency, %',fontsize="15")
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")
#plt.title("The effect of temperature on efficiency of a solar PV cell")

def f(x):
    return (x-25)*(-0.45)
x = np.linspace(0,50)
y = f(x)
plt.plot(x,y,color='r')

# %%
fig=plt.figure(figsize=(30,15))
cities = ["Lerwick","Stornoway","Nairn Druim","Tiree","Leuchars","Paisley","Eskdalemuir","Armagh","Whitby","Bradford","Sheffield","Valley"]
#efficiency = [5.4,4.86,4.815,4.5675,4.7475,4.2975,5.265,4.275,4.275,4.3875,4.095,3.915,4.095,4.2975,3.9375,4.1175,3.8925,3.7575,3.42,3.735,3.8925,3.915,3.42,3.735]
temp = np.array([17,15.8,15.7,15.15,15.55,14.55,16.7,14.5,14.5,14.75,14.1,13.7])
#eff_msi = [4.2,3.78,3.745,3.5525,3.6925,3.3425,4.095,3.325,3.325,3.4125,3.185,3.045,3.185,3.3425,3.0625,3.2025,3.0275,2.9225,2.66,2.905,3.0275,3.045,2.66,2.905]
m_si = temp * 0.35
p_si = temp * 0.435
a_si = temp * 0.234
gaas = temp * 0.09
cigs = temp * 0.36
cdte = temp * 0.21
psc = temp * 0.13
width = 0.1
x = np.arange(12)
plt.bar(x-0.3,m_si,width,color='b')
plt.bar(x-0.2,p_si,width,color='r')
plt.bar(x-0.1,a_si,width,color='g')
plt.bar(x,gaas,width,color='purple')
plt.bar(x+0.1,cigs,width,color='k')
plt.bar(x+0.2,cdte,width,color='orange')
plt.bar(x+0.3,psc,width,color='turquoise')

plt.xticks(range(len(cities)), cities, fontsize="20", rotation='vertical')
plt.yticks(range(0,9),fontsize="20")
plt.xlabel("Locations in the UK",fontsize="20")
plt.ylabel("Change in efficiency, %",fontsize="20")
plt.legend(["m-Si", "p-Si", "a-Si","GaAs","CIGS","CdTe","PSC"],fontsize="20") 
plt.show()

# %%
fig=plt.figure(figsize=(30,15))
temp1 = np.array([14.1,14.55,13.75,14.15,13.65,13.35,12.6,13.3,13.65,13.7,12.6,13.3])
cities1 = ["Waddington","Shawbury","Lowestoft","Aberporth","Ross-On-Wye","Oxford","Heathrow","Manston","Yeovilton","Hurn","Eastbourne","Camborne"]
m_si = temp1 * 0.35
p_si = temp1 * 0.435
a_si = temp1 * 0.234
gaas = temp1 * 0.09
cigs = temp1 * 0.36
cdte = temp1 * 0.21
psc = temp1 * 0.13
width = 0.1
x = np.arange(12)
plt.bar(x-0.3,m_si,width,color='b')
plt.bar(x-0.2,p_si,width,color='r')
plt.bar(x-0.1,a_si,width,color='g')
plt.bar(x,gaas,width,color='purple')
plt.bar(x+0.1,cigs,width,color='k')
plt.bar(x+0.2,cdte,width,color='orange')
plt.bar(x+0.3,psc,width,color='turquoise')

plt.xticks(range(len(cities1)), cities1, fontsize="20", rotation='vertical')
plt.yticks(range(0,9), fontsize="20")
plt.xlabel("Locations in the UK",fontsize="20")
plt.ylabel("Change in efficiency, %",fontsize="20")
plt.legend(["m-Si", "p-Si", "a-Si","GaAs","CIGS","CdTe","PSC"],fontsize="20") 
plt.show()

# %%
fig=plt.figure(figsize=(8,5))
cities2 = ["Lerwick","Stornoway","Nairn Druim","Tiree","Leuchars","Paisley","Eskdalemuir","Armagh","Whitby","Bradford","Sheffield","Valley","Waddington","Shawbury","Lowestoft","Aberporth","Ross-On-Wye","Oxford","Heathrow","Manston","Yeovilton","Hurn","Eastbourne","Camborne"]
sun = [86.9,90.1,124.2,116.5,120.1,113.9,94.3,109.2,144.4,118.6,116.5,133.1,132.4,113.3,153.7,117.2,120.6,143.5,126.2,152.2,128,138.8,160.2,126.9]
plt.bar(cities2,sun,color='g')
plt.xticks(range(len(cities2)), cities2, rotation='vertical', fontsize = "15")
plt.yticks(fontsize="15")
plt.xlabel("Locations in the UK", fontsize = "15")
plt.ylabel("Mean hours of sunshine per month", fontsize = "15")
plt.show()

# %%
fig=plt.figure(figsize=(50,50))
anglesmorning = np.arange(-90,0,7.5)
anglesevening = np.arange(0,105,7.5)
angles = np.concatenate((anglesmorning, anglesevening))

radiation = 0
r0 = np.zeros(len(angles))
n = 0
for i in range(len(angles)-2):
    r0[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))
       
plt.plot(angles,r0,linewidth=15,color='k',linestyle='--')

radiation = 0
r1 = np.zeros(len(angles))
n = 0.2
for i in range(len(angles)-2):
    r1[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))  
plt.plot(angles,r1,linewidth=10,color='pink')

radiation = 0
r2 = np.zeros(len(angles))
n = 0.4
for i in range(len(angles)-2):
    r2[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))  
plt.plot(angles,r2,linewidth=10,color='b')

radiation = 0
r3 = np.zeros(len(angles))
n = 0.6
for i in range(len(angles)-2):
    r3[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))  
plt.plot(angles,r3,linewidth=10,color='orange')

radiation = 0
r4 = np.zeros(len(angles))
n = 0.8
for i in range(len(angles)-2):
    r4[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))  
plt.plot(angles,r4,linewidth=10,color='g')

radiation = 0
r5 = np.zeros(len(angles))
n = 1
for i in range(len(angles)-2):
    r5[i] = ((990*np.sin(angles[i+2]))-30)*(1-(0.75*(n**3.4)))  
plt.plot(angles,r5,linewidth=10,color='r')

anglesaxis = [-90,-75,-60,-45,-30,-15,0,15,30,45,60,75,90]

plt.xticks(anglesaxis, fontsize="80")
plt.yticks(fontsize="80")
plt.xlabel("Solar elevation angle ($^\circ$)",fontsize="80")
plt.ylabel("Solar radiation (W/m$^2$)",fontsize="80")
fig.legend(["0% cloud cover", "20% cloud cover", "40% cloud cover","60% cloud cover","80% cloud cover","100% cloud cover"],bbox_to_anchor=(1.2,0.33),fontsize="80")

# %%
fig=plt.figure(figsize=(15,10))
cities3 = ["Lerwick","Stornoway","Nairn Druim","Tiree","Leuchars","Paisley","Eskdalemuir","Armagh","Whitby","Bradford","Sheffield","Valley","Waddington","Shawbury","Lowestoft","Aberporth","Ross-On-Wye","Oxford","Heathrow","Manston","Yeovilton","Hurn","Eastbourne","Camborne"]
sun = [86.9,90.1,124.2,116.5,120.1,113.9,94.3,109.2,144.4,118.6,116.5,133.1,132.4,113.3,153.7,117.2,120.6,143.5,126.2,152.2,128,138.8,160.2,126.9]
sunrange = [150.4,201.4,235.9,258.1,213.3,234.5,205.3,197.1,252.8,230.5,222.9,284.3,257.1,241.6,271.1,280.7,259.3,289.4,297.6,303.2,287.0,313.5,301.0,262.3]
x = np.arange(len(cities3))
width = 0.3
plt.bar(x+0.15,sunrange,width,color='turquoise')
plt.bar(x-0.15,sun,width,color='g')
plt.xticks(range(len(cities3)), cities3, rotation='vertical',fontsize="18")
plt.yticks(fontsize="18")
plt.xlabel("Locations in the UK",fontsize="20")
plt.ylabel("Hours",fontsize="20")
plt.legend(["Range of hours of sunlight from 2019-2023","Hours of sunlight per month"],fontsize="18")
plt.show()

# %%
fig=plt.figure()
cities4 = ["Lerwick","Stornoway","Nairn Druim","Tiree","Leuchars","Paisley","Eskdalemuir","Armagh","Whitby","Bradford","Sheffield","Valley","Waddington","Shawbury","Lowestoft","Aberporth","Ross-On-Wye","Oxford","Heathrow","Manston","Yeovilton","Hurn","Eastbourne","Camborne"]
sun1 = np.array([86.9,90.1,124.2,116.5,120.1,113.9,94.3,109.2,144.4,118.6,116.5,133.1,132.4,113.3,153.7,117.2,120.6,143.5,126.2,152.2,128,138.8,160.2,126.9])
sunrange1 = np.array([150.4,201.4,235.9,258.1,213.3,234.5,205.3,197.1,252.8,230.5,222.9,284.3,257.1,241.6,271.1,280.7,259.3,289.4,297.6,303.2,287.0,313.5,301.0,262.3])

evaluation = np.subtract(sunrange1,sun1)
plt.bar(cities4,evaluation,color='r')
plt.xticks(range(len(cities4)), cities4, rotation='vertical',fontsize="9")
plt.yticks(fontsize="9")
plt.xlabel("Locations in the UK",fontsize="12")
plt.ylabel("$\mu - (h_{max}-h_{min})$",fontsize="12")
plt.show()

# %%
fig=plt.figure(figsize=(30,15))
cities = ["Lerwick","Stornoway","Nairn Druim","Tiree","Leuchars","Paisley","Eskdalemuir","Armagh","Whitby","Bradford","Sheffield","Valley"]
#efficiency = [5.4,4.86,4.815,4.5675,4.7475,4.2975,5.265,4.275,4.275,4.3875,4.095,3.915,4.095,4.2975,3.9375,4.1175,3.8925,3.7575,3.42,3.735,3.8925,3.915,3.42,3.735]
temp = np.array([17,15.8,15.7,15.15,15.55,14.55,16.7,14.5,14.5,14.75,14.1,13.7])
#eff_msi = [4.2,3.78,3.745,3.5525,3.6925,3.3425,4.095,3.325,3.325,3.4125,3.185,3.045,3.185,3.3425,3.0625,3.2025,3.0275,2.9225,2.66,2.905,3.0275,3.045,2.66,2.905]
m_si = temp * 0.35
p_si = temp * 0.435
a_si = temp * 0.234
gaas = temp * 0.09
cigs = temp * 0.36
cdte = temp * 0.21
psc = temp * 0.13
width = 0.1
x = np.arange(12)
plt.bar(x-0.3,m_si,width,color='b')
plt.bar(x-0.2,p_si,width,color='r')
plt.bar(x-0.1,a_si,width,color='g')
plt.bar(x,gaas,width,color='turquoise')
plt.bar(x+0.1,cigs,width,color='k')
plt.bar(x+0.2,cdte,width,color='orange')
plt.bar(x+0.3,psc,width,color='purple')

plt.xticks(range(len(cities)), cities, fontsize="40", rotation='vertical')
plt.yticks(range(0,9),fontsize="40")
plt.xlabel("Locations in the UK",fontsize="40")
plt.ylabel("Change in efficiency, %",fontsize="40")
plt.legend(["m-Si", "p-Si", "a-Si","GaAs","CIGS","CdTe","PSC"],loc='upper center',ncol=7,fontsize="30") 
plt.show()

# %%
fig=plt.figure(figsize=(30,15))
temp1 = np.array([14.1,14.55,13.75,14.15,13.65,13.35,12.6,13.3,13.65,13.7,12.6,13.3])
cities1 = ["Waddington","Shawbury","Lowestoft","Aberporth","Ross-On-Wye","Oxford","Heathrow","Manston","Yeovilton","Hurn","Eastbourne","Camborne"]
m_si = temp1 * 0.35
p_si = temp1 * 0.435
a_si = temp1 * 0.234
gaas = temp1 * 0.09
cigs = temp1 * 0.36
cdte = temp1 * 0.21
psc = temp1 * 0.13
width = 0.1
x = np.arange(12)
plt.bar(x-0.3,m_si,width,color='b')
plt.bar(x-0.2,p_si,width,color='r')
plt.bar(x-0.1,a_si,width,color='g')
plt.bar(x,gaas,width,color='turquoise')
plt.bar(x+0.1,cigs,width,color='k')
plt.bar(x+0.2,cdte,width,color='orange')
plt.bar(x+0.3,psc,width,color='purple')

plt.xticks(range(len(cities1)), cities1, fontsize="40", rotation='vertical')
plt.yticks(range(0,9), fontsize="40")
plt.xlabel("Locations in the UK",fontsize="40")
plt.ylabel("Change in efficiency, %",fontsize="40")
plt.legend(["m-Si", "p-Si", "a-Si","GaAs","CIGS","CdTe","PSC"],loc='upper center',ncol=7,fontsize="30") 
plt.show()
